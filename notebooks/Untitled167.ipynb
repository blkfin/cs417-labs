# %% [markdown]
# <a href="https://colab.research.google.com/github/blkfin/cs417-labs/blob/main/notebooks/Untitled167.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%javascript
# let x = 5;
# element.textContent = `number is ${x}`;          // prints into the cell output
